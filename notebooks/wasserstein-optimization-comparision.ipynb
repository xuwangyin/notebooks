# %%
import torch
import torch.autograd
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import torch.optim as optim
import time
from matplotlib import animation, rc
from IPython.display import HTML
from IPython import display
import ot
import ot.plot

# %%
def generateTheta(L,endim):
    # This function generates L random samples from the unit `ndim'-u
    theta=[w/np.sqrt((w**2).sum()) for w in np.random.normal(size=(L,endim))]
    return np.asarray(theta).T

def sw_dist(f, g):
    D = f.shape[1]
    L=100 # Number of random projections
    theta = torch.from_numpy(generateTheta(L, D))
    projg = torch.mm(g, theta)
    projg_sorted = torch.topk(projg, k=N, dim=0)[0]
    projf = torch.mm(f, theta)
    dist = torch.mean((torch.topk(projf, k=N, dim=0)[0] - projg_sorted)**2)
    return dist

def w2_dist(f, g):
    M = ot.dist(f.data.numpy(), g.data.numpy(), metric='sqeuclidean')
    G = ot.emd(a, b, M)
    ix1, ix2 = np.nonzero(G)
    dist = torch.mean(torch.sum((f - g[ix2])**2, dim=1))
    return dist

def sinkhorn_dist(f, g, reg):
    M = ot.dist(f.data.numpy(), g.data.numpy(), metric='sqeuclidean')
    G = ot.sinkhorn(a, b, M, reg=reg)
    ix2 = np.argmax(G, axis=1)
    dist = torch.mean(torch.sum((f - g[ix2])**2, dim=1))
    return dist

# %%
np.random.seed(12345)
N = 10
d = 2
a, b = np.ones((N,)) / N, np.ones((N,)) / N  # points have equal probability of 1/N
f0 = np.random.rand(N, 2) - .5;
theta = 2 * np.pi * np.random.rand(1, N)
r = .99 + .01 * np.random.randn(1, N)
g0 = np.vstack([np.cos(theta) * r, np.sin(theta) * r]).T

# %%
def f2g(dist_fn, ax, title, **kwargs):
    f = torch.from_numpy(f0.copy())
    f.requires_grad = True
    g = torch.from_numpy(g0.copy())

    ax.axis('equal')
    optimizer = optim.SGD([f], lr=1)
    imgs = []
    for i in range(10):
#         ax.cla()
        ax.set_xlim(-2, 2)
        ax.set_ylim(-2, 2)
        ax.set_title(title)
        img = ax.plot(f.data.numpy()[:, 0], f.data.numpy()[:, 1], 'bo',
                      g0[:, 0], g0[:, 1], 'ro')
        imgs.append(img)
        optimizer.zero_grad()
        dist = dist_fn(f, g, **kwargs)
        dist.backward()
        optimizer.step()
        display.clear_output(wait=True)
        display.display(plt.gcf())
        time.sleep(1e-3)
    return imgs

# %%
fig, axes = plt.subplots(ncols=3, figsize=(15, 5))
titles = ['sliced wasserstein distance', 'wasserstein distance', 'sinkhorn distance']
kwargs = [{}, {}, {'reg': 0.1}]
dist_fns = [sw_dist, w2_dist, sinkhorn_dist]
captures = []
for ax, dist_fn, title, args in zip(axes, dist_fns, titles, kwargs):
    frames = f2g(dist_fn, ax, title, **args)
    captures.append(frames)
frames = [f1 + f2 + f3 for f1, f2, f3 in zip(*captures)]
ani = animation.ArtistAnimation(fig, frames, interval=200, repeat=True)
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgce8314a381ad400bb85ef170c94667dc">
#     <br>
#     <input id="_anim_sliderce8314a381ad400bb85ef170c94667dc" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="animce8314a381ad400bb85ef170c94667dc.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animce8314a381ad400bb85ef170c94667dc.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="animce8314a381ad400bb85ef170c94667dc.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="animce8314a381ad400bb85ef170c94667dc.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="animce8314a381ad400bb85ef170c94667dc.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="animce8314a381ad400bb85ef170c94667dc.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="animce8314a381ad400bb85ef170c94667dc.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="
# rwcNGqRvfvOb/tepqan66KOPJEn33XefUlNTFRsbqxEjRmjdunX+cYG2nRMnTujmm29W7969FR8f\
# r7y8PO3Zs0fSubf5yy+/XPfff7969+7tP+srPz9fcXFx6tOnj6ZNmybpi+1z+PDhiomJ0R/+8AdJ\
# 586r09v9ww8/rKlTp+rWW29Vz549lZWVpfLy8oDr7PXXX9eQIUMUFxenWbNmNcmeM7MqUM56vV6V\
# lJTo8ccfV0xMjH/9z58/XwMHDlTPnj01dOhQ/elPf2r2uf/v//0/JSQk6Etf+pJWrVrlf/989z2A\
# EwQ6Xjvz0pLTx2tLlixR//791adPH82bN6/Fz6uvr9eNN96ob3zjG/7jprq6uoAZ8emnn2rMmDGK\
# j49XVlaWXnnlFf97M2bM0D333KOJEyeqR48eevPNNzVjxgzNnDlTkyZNUs+ePTVy

# %%
fig, axes = plt.subplots(ncols=3, figsize=(15, 5))
titles = ['sinkhorn distance lambda=0.1', 'sinkhorn distance lambda=1.0', 'sinkhorn distance lambda=10.0']
kwargs = [{'reg': 0.1}, {'reg': 1.0}, {'reg': 10}]
dist_fns = [sinkhorn_dist, sinkhorn_dist, sinkhorn_dist]
captures = []
for ax, dist_fn, title, args in zip(axes, dist_fns, titles, kwargs):
    frames = f2g(dist_fn, ax, title, **args)
    captures.append(frames)
frames = [f1 + f2 + f3 for f1, f2, f3 in zip(*captures)]
ani = animation.ArtistAnimation(fig, frames, interval=200, repeat=True)
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imge9c233d2b28345568fbd50212100cfe4">
#     <br>
#     <input id="_anim_slidere9c233d2b28345568fbd50212100cfe4" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anime9c233d2b28345568fbd50212100cfe4.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anime9c233d2b28345568fbd50212100cfe4.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anime9c233d2b28345568fbd50212100cfe4.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anime9c233d2b28345568fbd50212100cfe4.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anime9c233d2b28345568fbd50212100cfe4.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anime9c233d2b28345568fbd50212100cfe4.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anime9c233d2b28345568fbd50212100cfe4.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anime9c233d2b28345568fbd50212100cfe4.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anime9c233d2b28345568fbd50212100cfe4.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anime9c233d2b28345568fbd50212100cfe4.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selecte9c233d2b28345568fbd50212100cfe4" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imge9c233d2b28345568fbd50212100cfe4";
#     var slider_id = "_anim_slidere9c233d2b28345568fbd50212100cfe4";
#     var loop_select_id = "_anim_loop_selecte9c233d2b28345568fbd50212100cfe4";
#     var frames = new Array(10);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4xLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvDW2N/gAAIABJREFUeJzt3XtwVGWe//FPY4wmhDuJhA6EwiiG\
# YEhBEJxSZJCLogZUhGAUWNQo4qqztSq7/LzhoIy1s+U6OGqLymUieEODDrCKwoiMivG6A+pEhRDC\
# Ra7KNQnh+f3RRUObBBLS6XOe0+9XFdXp009Of88J53O6vn0uPmOMEQAAAAAAgMVaOF0AAAAAAABA\
# U9HgAAAAAAAA1qPBAQAAAAAArEeDAwAAAAAAWI8GBwAAAAAAsB4NDgAAAAAAYD0aHAAAAAAAwHo0\
# OAAAAAAAgPVocAAAAAAAAOvR4AAAAAAAANajwQEAAAAAAKxHgwMAAAAAAFiPBgcAAAAAALAeDQ4A\
# AAAAAGA9GhwAAAAAAMB6NDgAAAAAAID1aHAAAAAAAADr0eAAAAAAAADWo8EBAAAAAACsR4MDAAAA\
# AABYjwYHAAAAAACwHg0OAAAAAABgPRocAAAAAADAejQ4AAAAAACA9WhwAAAAAAAA69HgAAAAAAAA\
# 1qPBAes8+uijuvnmmxs09qGHHtINN9zQ6Nec0K1bNy1fvlxS45bRbTZs2CCfz6fDhw9HfN6N/ZtN\
# nDhR/+///b+I1wHUhWxyN7IJsYQ8cjfyCGg+NDhgnf/8z//U7NmznS6jWTV0GQcNGuT5deE2lZWV\
# mjRpklq3bq1OnTrpv//7v+sd+49//EPDhw9Xx44d5fP5olglnEA2HUM2Rd8rr7yi3/zmN0pMTNSg\
# QYNOOv6ll15Senq6WrZsqVGjRmnXrl3NXySihjw6hjyKvpPl0Zdffqm+ffsqMTFRffv21Zdfflnv\
# vHbt2qWrr75aLVu2VHp6ul566aVmrBxeQIMDiICamhqnS0CUPPTQQyotLVVZWZlWrFihxx9/XMuW\
# Latz7Omnn64xY8bo+eefj3KVQBDZFDvat2+vu+++W1OnTj3p2LVr1+rWW2/V/PnztW3bNiUmJur2\
# 22+PQpWIZeRR7DhRHlVVVWnkyJG64YYbtHv3bk2YMEEjR45UVVVVnfOaMmWK4uPjtW3bNhUVFWny\
# 5Mlau3Ztcy8CLEaDA671hz/8QX6/X61atVKPHj303nvvSQo/9O7oIX5z585V165d1bFjR82YMaPO\
# +VVXV2vcuHG69tprQyFaVVWl8ePHq1WrVsrKylJJSUlo/DfffKNBgwapbdu2ysrK0uLFi0OvTZw4\
# UZMnT9aIESPUsmVLrVixQhMnTtSUKVN0xRVXqFWrVurfv79++OGHepdv/vz5Sk9PV4cOHWrVfPwy\
# Hjp0SDfccIM6dOigtm3bql+/ftq2bZumTZumVatW6Y477lBSUpLuuOMOSdJdd92lLl26qHXr1urb\
# t69WrVoVNt8xY8bUu8zl5eW65pprlJycrA4dOoTmKUkvvPCCMjMz1a5dOw0fPlxlZWUn+Osd8+KL\
# LyozM1OtWrVS9+7d9eyzz4ZeW7lypdLS0vT4448rJSVFqampevPNN7VkyRKde+65at++vR599NGw\
# +R06dEhjx45Vq1at1KdPH3311Veh17744gv16dNHrVq10tixY3Xo0KHQa7t379aVV16p5ORktWvX\
# TldeeaU2bdrUoGU43ty5c3X//ferXbt2yszM1C233KI5c+bUObZHjx666aablJWV1ej3gXuRTWST\
# G7NpyJAhGjNmjDp37nzSsUVFRbrqqqs0cOBAJSUl6ZFHHtGiRYu0d+/eRr8vnEUekUe25dHKlSt1\
# +PBh3X333TrjjDN05513yhij999/v9bY/fv36/XXX9cjjzyipKQkXXTRRcrLy9P8+fMbXRNiBw0O\
# uNJ3332nWbNm6dNPP9XevXv1v//7v+rWrVu94z/88EN99913eu+99zR9+nR98803

# %%
N = 500 # number of data points
a, b = np.ones((N,)) / N, np.ones((N,)) / N  # points have equal probability of 1/N
f = np.random.randn(N, 10) # dimension is 10000
g = np.random.randn(N, 10)
M = ot.dist(f, g, metric='sqeuclidean')

# %%
# %timeit M = ot.dist(f, g, metric='sqeuclidean')
# Out:
# 3.81 ms ± 225 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit G = ot.sinkhorn(a, b, M, reg=1.0)
# Out:
# 32.3 ms ± 8.88 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit G = ot.sinkhorn(a, b, M, reg=0.1)
# Out:
# 139 ms ± 4.87 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit G = ot.emd(a, b, M)
# Out:
# 26.5 ms ± 317 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
